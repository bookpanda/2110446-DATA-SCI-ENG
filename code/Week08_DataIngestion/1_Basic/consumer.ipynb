# %%
# import required libraries
from kafka import KafkaConsumer

# %%
# Connect to kafka broker running in your local host (docker). Change this to your kafka broker if needed
kafka_broker = 'localhost:9092'

# %%
consumer = KafkaConsumer(
    'sample',
    bootstrap_servers=[kafka_broker],
    enable_auto_commit=True,
    value_deserializer=lambda x: x.decode('utf-8'))

# %%
print('Running Consumer')
for message in consumer:
    print('[{}:{}] {}'.format(message.timestamp, message.offset, message.value))
# Out:
# Running Consumer
# [1742891723241:5] message #5 from producer-0
# [1742891725246:6] message #6 from producer-0
# [1742891727252:7] message #7 from producer-0
# [1742891729257:8] message #8 from producer-0
# [1742891731258:9] message #9 from producer-0
# [1742891733299:10] message #10 from producer-0
# [1742891733380:11] message #0 from another producer
# [1742891735304:12] message #11 from producer-0
# [1742891736382:13] message #1 from another producer
# [1742891737308:14] message #12 from producer-0
# [1742891739314:15] message #13 from producer-0
# [1742891739384:16] message #2 from another producer
# [1742891741320:17] message #14 from producer-0
# [1742891742389:18] message #3 from another producer
# [1742891743324:19] message #15 from producer-0
# [1742891745330:20] message #16 from producer-0
# [1742891745394:21] message #4 from another producer
# [1742891747335:22] message #17 from producer-0
# [1742891748399:23] message #5 from another producer
# [1742891749340:24] message #18 from producer-0
# [1742891751345:25] message #19 from producer-0
# [1742891751404:26] message #6 from another producer
# [1742891753350:27] message #20 from producer-0
# [1742891754409:28] message #7 from another producer
# [1742891755356:29] message #21 from producer-0
# [1742891757357:30] message #22 from producer-0
# [1742891757415:31] message #8 from another producer
# [1742891759360:32] message #23 from producer-0
# [1742891760416:33] message #9 from another producer
# [1742891761366:34] message #24 from producer-0
# [1742891763371:35] message #25 from producer-0
# [1742891763422:36] message #10 from another producer
# [1742891765376:37] message #26 from producer-0
# [1742891766426:38] message #11 from another producer
# [1742891767377:39] message #27 from producer-0
# [1742891769382:40] message #28 from producer-0
# [1742891769431:41] message #12 from another producer
# [1742891771387:42] message #29 from producer-0
# [1742891772436:43] message #13 from another producer
# [1742891773393:44] message #30 from producer-0
# [1742891775394:45] message #31 from producer-0
# [1742891775442:46] message #14 from another producer
# [1742891777404:47] message #32 from producer-0
# [1742891778444:48] message #15 from another producer
# [1742891779410:49] message #33 from producer-0
# [1742891781416:50] message #34 from producer-0
# [1742891781450:51] message #16 from another producer
# [1742891783421:52] message #35 from producer-0
# [1742891784451:53] message #17 from another producer
# [1742891785425:54] message #36 from producer-0
# [1742891787427:55] message #37 from producer-0
# [1742891787456:56] message #18 from another producer
# [1742891789431:57] message #38 from producer-0
# [1742891790461:58] message #19 from another producer
# [1742891791436:59] message #39 from producer-0
# [1742891793441:60] message #40 from producer-0
# [1742891793466:61] message #20 from another producer
# [1742891795446:62] message #41 from producer-0
# [1742891796471:63] message #21 from another producer
# [1742891797449:64] message #42 from producer-0
# [1742891799455:65] message #43 from producer-0
# [1742891799477:66] message #22 from another producer
# [1742891801459:67] message #44 from producer-0
# [1742891802481:68] message #23 from another producer
# [1742891803464:69] message #45 from producer-0
# [1742891898611:148] message #55 from another producer
# [1742891899675:149] message #93 from producer-0
# [1742891901616:150] message #56 from another producer
# [1742891901677:151] message #94 from producer-0
# [1742891903682:152] message #95 from producer-0
# [1742891904618:153] message #57 from another producer
# [1742891905687:154] message #96 from producer-0
# [1742891907623:155] message #58 from another producer
# [1742891907688:156] message #97 from producer-0
# [1742891909693:157] message #98 from producer-0
# [1742891910626:158] message #59 from another producer
# [1742891911698:159] message #99 from producer-0
# [1742891913632:160] message #60 from another producer
# [1742891916637:161] message #61 from another producer
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 print('Running Consumer')
# ----> 2 for message in consumer:
#       3     print('[{}:{}] {}'.format(message.timestamp, message.offset, message.value))
#
# File ~/Code/courses/DATA-SCI/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:1168, in KafkaConsumer.__next__(self)
#    1166     self._iterator = self._message_generator_v2()
#    1167 try:
# -> 1168     return next(self._iterator)
#    1169 except StopIteration:
#    1170     self._iterator = None
#
# File ~/Code/courses/DATA-SCI/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:1140, in KafkaConsumer._message_generator_v2(self)
#    1138 def _message_generator_v2(self):
#    1139     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1140     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1141     for tp, records in six.iteritems(record_map):
#    1142         # Generators are stateful, and it is possible that the tp / records
#    1143         # here may become stale during iteration -- i.e., we seek to a
#    1144         # different offset, pause consumption, or lose assignment.
#    1145         for record in records:
#    1146             # is_fetchable(tp) should handle assignment changes and offset
#    1147             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1148             # outer function destroying the existing iterator/generator
#    1149             # via self._iterator = None
#
# File ~/Code/courses/DATA-SCI/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:679, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     677 inner_timeout_ms = timeout_ms_fn(timeout_ms, None)
#     678 while not self._closed:
# --> 679     records = self._poll_once(inner_timeout_ms(), max_records, update_offsets=update_offsets)
#     680     if records:
#     681         return records
#
# File ~/Code/courses/DATA-SCI/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:722, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     719 if records:
#     720     return records
# --> 722 self._client.poll(timeout_ms=inner_timeout_ms(self._coordinator.time_to_next_poll() * 1000))
#     723 # after the long poll, we should check whether the group needs to rebalance
#     724 # prior to returning data so that the group can stabilize faster
#     725 if self._coordinator.need_rejoin():
#
# File ~/Code/courses/DATA-SCI/.venv/lib/python3.12/site-packages/kafka/client_async.py:683, in KafkaClient.poll(self, timeout_ms, future)
#     676         timeout = min(
#     677             user_timeout_ms,
#     678             metadata_timeout_ms,
#     679             idle_connection_timeout_ms,
#     680             request_timeout_ms)
#     681         timeout = max(0, timeout)  # avoid negative timeouts
# --> 683     self._poll(timeout / 1000)
#     685 # called without the lock to avoid deadlock potential
#     686 # if handlers need to acquire locks
#     687 responses.extend(self._fire_pending_completed_requests())
#
# File ~/Code/courses/DATA-SCI/.venv/lib/python3.12/site-packages/kafka/client_async.py:726, in KafkaClient._poll(self, timeout)
#     723 self._register_send_sockets()
#     725 start_select = time.time()
# --> 726 ready = self._selector.select(timeout)
#     727 end_select = time.time()
#     728 if self._sensors:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/selectors.py:566, in KqueueSelector.select(self, timeout)
#     564 ready = []
#     565 try:
# --> 566     kev_list = self._selector.control(None, max_ev, timeout)
#     567 except InterruptedError:
#     568     return ready
#
# KeyboardInterrupt:
